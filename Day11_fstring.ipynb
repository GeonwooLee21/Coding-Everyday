# %% [markdown]
# # Python F-String 튜토리얼 / Python F-String Tutorial
#
# ## 학습 목표 / Learning Objectives
# - f-string의 개념과 사용법 이해하기
# - 다양한 포맷팅 기법 익히기
# - 실전 예제를 통해 f-string 활용법 배우기
#
# ---

# %% [markdown]
# ## 1. f-string 소개 / Introduction
#
# **f-string**은 Python 3.6부터 도입된 문자열 포맷팅 방법입니다.
#
# ### 기존 방법과의 비교 / Comparison with Old Methods

# %%
# 변수 정의 / Define variables
name = "김철수"
age = 25

# 1. % 포맷팅 (구식) / Old % formatting
msg1 = "이름: %s, 나이: %d" % (name, age)
print("방법 1:", msg1)

# 2. .format() 메서드 / .format() method
msg2 = "이름: {}, 나이: {}".format(name, age)
print("방법 2:", msg2)

# 3. f-string (권장) / f-string (recommended) ⭐
msg3 = f"이름: {name}, 나이: {age}"
print("방법 3:", msg3)
# Out:
# 방법 1: 이름: 김철수, 나이: 25
# 방법 2: 이름: 김철수, 나이: 25
# 방법 3: 이름: 김철수, 나이: 25

# %% [markdown]
# ### 💡 실습 / Practice
# 위 코드를 실행하고, 세 가지 방법의 결과를 비교해보세요!

# %% [markdown]
# ---
# ## 2. 기본 사용법 / Basic Usage
#
# ### 2.1 변수 삽입 / Variable Insertion

# %%
# 예제 1: 인사말 만들기 / Example 1: Creating a greeting
name = "이영희"
greeting = f"안녕하세요, {name}님!"
print(greeting)
# Out:
# 안녕하세요, 이영희님!

# %%
# 예제 2: 여러 변수 사용 / Example 2: Using multiple variables
first_name = "John"
last_name = "Doe"
full_name = f"{first_name} {last_name}"
print(full_name)
# Out:
# John Doe

# %%
# 예제 3: 학생 정보 출력 / Example 3: Student information
student_id = "2024001"
student_name = "박민수"
major = "컴퓨터공학"
grade = 2

info = f"학번: {student_id}, 이름: {student_name}, 전공: {major}, 학년: {grade}"
print(info)
# Out:
# 학번: 2024001, 이름: 박민수, 전공: 컴퓨터공학, 학년: 2

# %% [markdown]
# ### ✏️ 연습 문제 1 / Exercise 1
# 여러분의 정보로 자기소개 문장을 만들어보세요!

# %%
# 여기에 코드를 작성하세요 / Write your code here
my_name = "Geonwoo"  # 여러분의 이름
my_age = 24    # 여러분의 나이
my_hobby = "listening to music over a cup of coffee"  # 여러분의 취미

# f-string으로 자기소개 문장 만들기
introduction = f"Hello, my name is {my_name}. I'm {my_age} years old and, I love {my_hobby}!"
print(introduction)
# Out:
# Hello, my name is Geonwoo. I'm 24 years old and, I love listening to music over a cup of coffee!

# %% [markdown]
# ---
# ## 3. 표현식 사용 / Using Expressions
#
# ### 3.1 산술 연산 / Arithmetic Operations

# %%
# 직사각형 넓이 계산 / Rectangle area calculation
width = 10
length = 15

print(f"가로: {width}cm, 세로: {length}cm")
print(f"넓이: {width * length}cm²")
print(f"둘레: {2 * (width + length)}cm")
# Out:
# 가로: 10cm, 세로: 15cm
# 넓이: 150cm²
# 둘레: 50cm

# %%
# 평균 계산 / Average calculation
korean = 85
english = 92
math = 88

average = f"평균 점수: {(korean + english + math) / 3:.2f}점"
print(average)
# Out:
# 평균 점수: 88.33점

# %% [markdown]
# ### 3.2 함수 호출 / Function Calls

# %%
# 문자열 메서드 사용 / Using string methods
text = "hello world"

print(f"원본: {text}")
print(f"대문자: {text.upper()}")
print(f"첫 글자 대문자: {text.title()}")
print(f"길이: {len(text)}자")
# Out:
# 원본: hello world
# 대문자: HELLO WORLD
# 첫 글자 대문자: Hello World
# 길이: 11자

# %%
# 리스트 함수 / List functions
scores = [85, 92, 78, 95, 88]

print(f"점수 목록: {scores}")
print(f"최고 점수: {max(scores)}점")
print(f"최저 점수: {min(scores)}점")
print(f"평균: {sum(scores) / len(scores):.1f}점")
# Out:
# 점수 목록: [85, 92, 78, 95, 88]
# 최고 점수: 95점
# 최저 점수: 78점
# 평균: 87.6점

# %% [markdown]
# ### 3.3 조건 표현식 / Conditional Expressions

# %%
# 합격/불합격 판정 / Pass/Fail evaluation
score = 75
result = f"점수: {score}점 - {'합격' if score >= 60 else '불합격'}"
print(result)
# Out:
# 점수: 75점 - 합격

# %%
# 학점 계산 / Grade calculation
score = 87
grade = 'A' if score >= 90 else 'B' if score >= 80 else 'C' if score >= 70 else 'D' if score >= 60 else 'F'
print(f"{score}점 → 학점: {grade}")
# Out:
# 87점 → 학점: B

# %% [markdown]
# ### ✏️ 연습 문제 2 / Exercise 2
# 원의 반지름을 입력받아 넓이와 둘레를 계산하여 출력하세요. (π = 3.14159)

# %%
# 여기에 코드를 작성하세요 / Write your code here
radius = 5
pi = 3.14159

# 원의 넓이: π × r²
print(f'반지름이 {radius}인 원의 넓이는 {pi * radius ** 2}입니다.')
# 원의 둘레: 2 × π × r
print(f'반지름이 {radius}인 원의 둘레는 {pi * radius * 2}입니다.')
# Out:
# 반지름이 5인 원의 넓이는 78.53975입니다.
# 반지름이 5인 원의 둘레는 31.4159입니다.

# %% [markdown]
# ---
# ## 4. 숫자 포맷팅 / Number Formatting
#
# ### 4.1 소수점 자리수 / Decimal Places

# %%
# 원주율 표현 / Pi representation
pi = 3.141592653589793

print(f"원본: {pi}")
print(f"소수점 2자리: {pi:.2f}")
print(f"소수점 4자리: {pi:.4f}")
print(f"소수점 6자리: {pi:.6f}")
# Out:
# 원본: 3.141592653589793
# 소수점 2자리: 3.14
# 소수점 4자리: 3.1416
# 소수점 6자리: 3.141593

# %%
# 금액 계산 / Price calculation
price = 15000
quantity = 3
discount_rate = 0.15

total = price * quantity
discount = total * discount_rate
final_price = total - discount

print(f"단가: {price}원")
print(f"수량: {quantity}개")
print(f"소계: {total}원")
print(f"할인({discount_rate:.0%}): -{discount:.0f}원")
print(f"최종 금액: {final_price:.0f}원")
# Out:
# 단가: 15000원
# 수량: 3개
# 소계: 45000원
# 할인(15%): -6750원
# 최종 금액: 38250원

# %% [markdown]
# ### 4.2 천단위 구분자 / Thousands Separator

# %%
# 큰 숫자 표현 / Large number representation
population = 51000000
gdp = 1700000000000

print(f"인구: {population:,}명")
print(f"GDP: {gdp:,}원")
print(f"1인당 GDP: {gdp/population:,.0f}원")
# Out:
# 인구: 51,000,000명
# GDP: 1,700,000,000,000원
# 1인당 GDP: 33,333원

# %% [markdown]
# ### 4.3 퍼센트 표현 / Percentage

# %%
# 비율을 퍼센트로 / Ratio to percentage
correct = 85
total = 100
accuracy = correct / total

print(f"정답: {correct}/{total}")
print(f"정확도: {accuracy:.1%}")
print(f"정확도: {accuracy:.2%}")
# Out:
# 정답: 85/100
# 정확도: 85.0%
# 정확도: 85.00%

# %% [markdown]
# ### 4.4 진법 변환 / Base Conversion

# %%
# 다양한 진법으로 표현 / Various base representations
num = 255

print(f"10진수 (Decimal): {num}")
print(f"2진수 (Binary): {num:b}")
print(f"8진수 (Octal): {num:o}")
print(f"16진수 (Hexadecimal): {num:x}")
print(f"16진수 대문자 (Hex Upper): {num:X}")
# Out:
# 10진수 (Decimal): 255
# 2진수 (Binary): 11111111
# 8진수 (Octal): 377
# 16진수 (Hexadecimal): ff
# 16진수 대문자 (Hex Upper): FF

# %% [markdown]
# ### ✏️ 연습 문제 3 / Exercise 3
# 학생 5명의 점수를 리스트로 저장하고, 평균, 최고점, 최저점을 계산하여 포맷팅된 형태로 출력하세요.

# %%
# 여기에 코드를 작성하세요 / Write your code here
scores = [85, 92, 78, 95, 88]

# 평균 (소수점 2자리)
print(f'평균 : {sum(scores)/len(scores):.2f}')

# 최고점
print(f'평균 : {max(scores)}')

# 최저점
print(f'평균 : {min(scores)}')
# Out:
# 평균 : 87.60
# 평균 : 95
# 평균 : 78

# %% [markdown]
# ---
# ## 5. 문자열 정렬 / String Alignment
#
# ### 5.1 기본 정렬 / Basic Alignment

# %%
# 왼쪽/가운데/오른쪽 정렬 / Left/Center/Right alignment
word = "Python"

print(f"왼쪽 정렬 (Left):    '{word:<20}'")
print(f"가운데 정렬 (Center): '{word:^20}'")
print(f"오른쪽 정렬 (Right):  '{word:>20}'")
# Out:
# 왼쪽 정렬 (Left):    'Python              '
# 가운데 정렬 (Center): '       Python       '
# 오른쪽 정렬 (Right):  '              Python'

# %% [markdown]
# ### 5.2 패딩 문자 지정 / Padding Characters

# %%
# 다양한 패딩 문자 / Various padding characters
title = "Menu"

print(f"{title:*<30}")
print(f"{title:=^30}")
print(f"{title:->30}")
# Out:
# Menu**************************
# =============Menu=============
# --------------------------Menu

# %% [markdown]
# ### 5.3 표 만들기 / Creating Tables

# %%
# 제품 목록 표 / Product list table
print("="*50)
print(f"{'제품명':<15} {'가격':>15} {'재고':>10}")
print("="*50)
print(f"{'노트북':<15} {1500000:>15,} {25:>10}")
print(f"{'마우스':<15} {25000:>15,} {150:>10}")
print(f"{'키보드':<15} {85000:>15,} {80:>10}")
print(f"{'모니터':<15} {350000:>15,} {45:>10}")
print("="*50)
# Out:
# ...
# 제품명                          가격         재고
# ...
# 노트북                   1,500,000         25
# 마우스                      25,000        150
# 키보드                      85,000         80
# 모니터                     350,000         45
# ...

# %% [markdown]
# ### ✏️ 연습 문제 4 / Exercise 4
# 학생 성적표를 표 형식으로 만들어보세요.

# %%
# 여기에 코드를 작성하세요 / Write your code here
students = [
    {"name": "김철수", "korean": 85, "english": 92, "math": 88},
    {"name": "이영희", "korean": 90, "english": 87, "math": 95},
    {"name": "박민수", "korean": 78, "english": 85, "math": 82}
]

# 표 형식으로 출력
# 이름(왼쪽 정렬 10자리), 국어/영어/수학(오른쪽 정렬 8자리), 평균(소수점 1자리)
print(f'{'학생 성적표':^49}')
print('=' * 50)
print(f'{'이름':<10} {'국어':>8}{'영어':>8}{'수학':>8}{'평균':>10}')
print('-' * 50)
for student in students:
    name    = student["name"]
    korean  = student["korean"]
    english = student["english"]
    math    = student["math"]
    avg = (korean + english + math) / 3
    print(f'{name:<10} {korean:>8} {english:>8} {math:>8} {avg:>10.1f}')
print('=' * 50)
# Out:
#                      학생 성적표
# ...
# 이름               국어      영어      수학        평균
# --------------------------------------------------
# 김철수              85       92       88       88.3
# 이영희              90       87       95       90.7
# 박민수              78       85       82       81.7
# ...

# %% [markdown]
# ---
# ## 6. 날짜/시간 포맷팅 / DateTime Formatting

# %%
from datetime import datetime

now = datetime.now()

# 다양한 날짜 형식 / Various date formats
print(f"전체: {now}")
print(f"날짜: {now:%Y-%m-%d}")
print(f"시간: {now:%H:%M:%S}")
print(f"한국식: {now:%Y년 %m월 %d일}")
print(f"시간 포함: {now:%Y년 %m월 %d일 %H시 %M분}")
# Out:
# 전체: 2026-04-14 23:27:59.110891
# 날짜: 2026-04-14
# 시간: 23:27:59
# 한국식: 2026년 04월 14일
# 시간 포함: 2026년 04월 14일 23시 27분

# %%
# 날짜 계산 / Date calculation
from datetime import datetime, timedelta

today = datetime.now()
tomorrow = today + timedelta(days=1)
next_week = today + timedelta(weeks=1)

print(f"오늘: {today:%Y-%m-%d}")
print(f"내일: {tomorrow:%Y-%m-%d}")
print(f"다음 주: {next_week:%Y-%m-%d}")
# Out:
# 오늘: 2026-04-14
# 내일: 2026-04-15
# 다음 주: 2026-04-21

# %% [markdown]
# ---
# ## 7. 고급 기능 / Advanced Features
#
# ### 7.1 딕셔너리 사용 / Using Dictionaries

# %%
# 학생 정보 딕셔너리 / Student information dictionary
student = {
    "name": "박민수",
    "id": "2024001",
    "grade": 3,
    "major": "컴퓨터공학",
    "gpa": 3.85
}

profile = f"""
학생 프로필 / Student Profile
{'='*40}
이름: {student['name']}
학번: {student['id']}
학년: {student['grade']}학년
전공: {student['major']}
평점: {student['gpa']:.2f}
{'='*40}
"""
print(profile)
# Out:
# 학생 프로필 / Student Profile
# ...
# 이름: 박민수
# 학번: 2024001
# 학년: 3학년
# 전공: 컴퓨터공학
# 평점: 3.85
# ...

# %% [markdown]
# ### 7.2 디버깅 기능 (Python 3.8+) / Debugging (Python 3.8+)

# %%
# = 연산자로 변수명과 값 함께 출력 / Print variable name and value with =
x = 42
y = 3.14
name = "Python"

print(f"{x=}")
print(f"{y=:.2f}")
print(f"{name=}")
print(f"{x + y=}")
# Out:
# x=42
# y=3.14
# name='Python'
# x + y=45.14

# %% [markdown]
# ### 7.3 멀티라인 f-string / Multi-line f-string

# %%
# 보고서 생성 / Generate report
university = "경북대학교"
department = "컴퓨터학부"
students = 500
professors = 25
year = 2024

report = f"""
{'='*50}
       대학 정보 보고서 / University Report
{'='*50}
학교명: {university}
학과명: {department}
학생 수: {students:,}명
교수 수: {professors}명
학생/교수 비율: {students/professors:.1f}:1
보고 연도: {year}년
{'='*50}
"""
print(report)
# Out:
# ...
#        대학 정보 보고서 / University Report
# ...
# 학교명: 경북대학교
# 학과명: 컴퓨터학부
# 학생 수: 500명
# 교수 수: 25명
# 학생/교수 비율: 20.0:1
# 보고 연도: 2024년
# ...

# %% [markdown]
# ---
# ## 8. 종합 연습 문제 / Comprehensive Exercises
#
# ### 📝 프로젝트: 성적 관리 시스템 / Project: Grade Management System

# %%
# 학생 성적 데이터 / Student grade data
students = [
    {"name": "김철수", "student_id": "2024001", "korean": 85, "english": 92, "math": 88},
    {"name": "이영희", "student_id": "2024002", "korean": 90, "english": 87, "math": 95},
    {"name": "박민수", "student_id": "2024003", "korean": 78, "english": 85, "math": 82},
    {"name": "최지은", "student_id": "2024004", "korean": 95, "english": 90, "math": 92}
]

# TODO: 다음 기능을 구현하세요 / Implement the following features:
# 1. 각 학생의 총점과 평균 계산
# 2. 전체 학생의 과목별 평균 계산
# 3. 성적표를 표 형식으로 출력
#    - 학번, 이름, 국어, 영어, 수학, 총점, 평균, 학점
#    - 평균은 소수점 2자리, 90점 이상 A, 80점 이상 B, 70점 이상 C, 60점 이상 D, 나머지 F

# 여기에 코드를 작성하세요 / Write your code here
print('='*37)
print(f'{'성적표':^37}')
print('-'*37)
print(f'{'학번':>6} {'이름':>3} {'국어':} {'영어':} {'수학':} {'총점':} {'평균':>3} {'학점':>3}')
print('-'*37)
for student in students:
    name    = student["name"]
    id      = student["student_id"]
    korean  = student["korean"]
    english = student["english"]
    math    = student["math"]

    # 1. 각 학생의 총점과 평균 계산
    total = korean + english + math
    avg   = total / 3 # 과목 수 = 3

    # 2. 전체 학생의 과목별 평균 계산
    korean_total, english_total, math_total = 0, 0, 0
    korean_total  += korean
    english_total += english
    math_total    += math

    korean_avg  = korean_total / len(students)
    english_avg = english_total / len(students)
    math_avg    = math_total / len(students)

    # 3. 성적표를 표 형식으로 출력
    #    - 학번, 이름, 국어, 영어, 수학, 총점, 평균, 학점
    #    - 평균은 소수점 2자리, 90점 이상 A, 80점 이상 B, 70점 이상 C, 60점 이상 D, 나머지 F
    if   avg >= 90:
        grade = 'A'
    elif avg >= 80:
        grade = 'B'
    elif avg >= 70:
        grade = 'C'
    elif avg >= 60:
        grade = 'D'
    elif avg >= 50:
        grade = 'F' 
    print(f'{id} {name} {korean:}  {english}  {math} {total} {avg:.2f} {grade:>2}')
print('='*37)
# Out:
# ...
#                  성적표
# -------------------------------------
#     학번  이름 국어 영어 수학 총점  평균  학점
# -------------------------------------
# 2024001 김철수 85  92  88 265 88.33  B
# 2024002 이영희 90  87  95 272 90.67  A
# 2024003 박민수 78  85  82 245 81.67  B
# 2024004 최지은 95  90  92 277 92.33  A
# ...

# %% [markdown]
# ### 📝 프로젝트: 쇼핑몰 영수증 / Project: Shopping Receipt

# %%
# 상품 데이터 / Product data
products = [
    {"name": "노트북", "price": 1500000, "quantity": 1},
    {"name": "마우스", "price": 25000, "quantity": 2},
    {"name": "키보드", "price": 85000, "quantity": 1},
    {"name": "모니터", "price": 350000, "quantity": 1}
]

# TODO: 영수증 형식으로 출력하세요 / Print in receipt format:
# - 상점명, 날짜/시간
# - 각 상품의 이름, 단가, 수량, 금액
# - 소계, 부가세(10%), 총액
# - 모든 금액은 천단위 구분자 사용

from datetime import datetime

# 여기에 코드를 작성하세요 / Write your code here
now = datetime.now()
print('건우네 전자상가')
print()
print(f"승인 일시: {f'{now:%Y-%m-%d %H:%M:%S}':>26}")
print('-' * 35)
print(f"상품명 {'단가':>11} 수량 {'금액':>11}")
print('-' * 35)
subtotal = 0
for product in products:
    name     = product["name"]
    price    = product["price"]
    quantity = product["quantity"]
    subtotal += (price * quantity)

    print(f'{name} {price:>10,}원   {quantity}  {price * quantity:>10,}원')
print('-' * 35)
VAT = int(subtotal*0.1) # VAT를 정수로 처리하면 더 깔끔함
print(f'소계: {subtotal:>28,}원')
print(f'부가세: {VAT:>27,.0f}원') # 포맷팅 순서 : [fill][align][width][,][.precision][type]
print(f'총액: {subtotal+VAT:>28,}원')
# Out:
# 건우네 전자상가
#
# 승인 일시:        2026-04-14 23:58:30
# -----------------------------------
# 상품명          단가 수량          금액
# -----------------------------------
# 노트북  1,500,000원   1   1,500,000원
# 마우스     25,000원   2      50,000원
# 키보드     85,000원   1      85,000원
# 모니터    350,000원   1     350,000원
# -----------------------------------
# 소계:                    1,985,000원
# 부가세:                     198,500원
# 총액:                    2,183,500원

# %% [markdown]
# ---
# ## 9. 정리 / Summary
#
# ### f-string 주요 문법 정리 / Key Syntax Summary
#
# | 기능 / Feature | 문법 / Syntax | 예시 / Example |
# |---------------|--------------|---------------|
# | 기본 변수 / Basic | `f"{var}"` | `f"{name}"` |
# | 소수점 / Decimal | `f"{var:.nf}"` | `f"{pi:.2f}"` |
# | 천단위 구분 / Comma | `f"{var:,}"` | `f"{price:,}"` |
# | 퍼센트 / Percent | `f"{var:.n%}"` | `f"{ratio:.1%}"` |
# | 왼쪽 정렬 / Left | `f"{var:<n}"` | `f"{text:<10}"` |
# | 가운데 정렬 / Center | `f"{var:^n}"` | `f"{text:^10}"` |
# | 오른쪽 정렬 / Right | `f"{var:>n}"` | `f"{text:>10}"` |
# | 2진수 / Binary | `f"{var:b}"` | `f"{num:b}"` |
# | 16진수 / Hex | `f"{var:x}"` | `f"{num:x}"` |
# | 디버깅 / Debug | `f"{var=}"` | `f"{x=}"` |
#
# ### 학습 체크리스트 / Learning Checklist
#
# - [✓] f-string의 기본 개념 이해
# - [✓] 변수와 표현식 삽입 방법
# - [✓] 숫자 포맷팅 (소수점, 천단위, 퍼센트)
# - [✓] 문자열 정렬과 패딩
# - [✓] 날짜/시간 포맷팅
# - [✓] 딕셔너리와 복잡한 데이터 다루기
# - [✓] 실전 프로젝트 완성
#
# ---
#
# ## 🎓 수고하셨습니다! / Great Job!
#
# f-string을 마스터하면 Python 코드가 훨씬 더 깔끔하고 읽기 쉬워집니다.
# 많은 연습을 통해 익숙해지세요! 💪
#
# Mastering f-strings will make your Python code much cleaner and more readable.
# Practice a lot to get comfortable! 💪
